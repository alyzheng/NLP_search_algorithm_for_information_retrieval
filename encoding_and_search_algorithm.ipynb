# %%
import nltk
import pandas as pd
from nltk.util import ngrams
from nltk.metrics import jaccard_distance
from collections import Counter
from sentence_transformers import SentenceTransformer, CrossEncoder, util

# %%
data = pd.read_excel("output.xlsx")

# %%
data.head()
# Out:
#       brand   child_category parent category                 offer retailer
# 0     prego  red pasta sauce     pasta sauce
# 1      ragu  red pasta sauce     pasta sauce
# 2  classico  red pasta sauce     pasta sauce
# 3       heb  red pasta sauce     pasta sauce
# 4   barilla  red pasta sauce     pasta sauce  barilla® pesto sauce

# %% [markdown]
# ### Create String for Encoding

# %% [markdown]
# Sentence Transformer is sensitive to sentence instead of single word, so I aggregated variables into sentences within each row, improving overall performance

# %%
offer_embedding_string = []
for index, row in data.iterrows():
    sentence =  'for the brand: ' + row['brand'] + ', the retailer is ' + row['retailer'] + ', the product category is ' + row['child_category'] + ', which belongs to parent category ' + row['parent category'] + ', now the offer is: ' + row['offer']
    offer_embedding_string.append(sentence)

# %%
offer_embedding_string
# Out:
# ['for the brand: prego, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: ragu, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: classico, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: heb, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: barilla, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: barilla® pesto sauce',
#  'for the brand: barilla, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: barilla® pasta, select varieties, buy 2',
#  'for the brand: barilla, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: barilla® pasta, select varieties, buy 3',
#  'for the brand: barilla, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: barilla® pasta, select varieties, buy 4',
#  'for the brand: barilla, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: barilla® pasta, select varieties, buy 2',
#  'for the brand: the silver palate, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: publix, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  "for the brand: rao's, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: michael angelo's® or rao's® frozen entrees, spend $10",
#  "for the brand: rao's, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: rao's® frozen pizza",
#  "for the brand: rao's, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: rao's®, pasta or sauce, spend $10",
#  'for the brand: hill country fare, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: raos, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: kens, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: kroger, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: francesco rinaldi, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: simple truth, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: greenwise, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: private selection, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: bertolli, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: signature select, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: heb organics, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: weis, the retailer is , the product category is red pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: classico, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: prego, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: ragu, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  "for the brand: rao's, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: michael angelo's® or rao's® frozen entrees, spend $10",
#  "for the brand: rao's, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: rao's® frozen pizza",
#  "for the brand: rao's, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: rao's®, pasta or sauce, spend $10",
#  'for the brand: kroger, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: simple truth, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: publix, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: heb, the retailer is , the product category is alfredo & white pasta sauce, which belongs to parent category pasta sauce, now the offer is: ',
#  'for the brand: old el paso, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: kinders, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: betty crocker, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: goya, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: goya® coconut water',
#  'for the brand: goya, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: goya® adobo seasoning, 8 ounce+',
#  'for the brand: dole, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: knorr, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: dr pepper, the retailer is united supermarkets, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: dr pepper®, regular or zero sugar strawberries and cream 12 pack, at select retailers',
#  'for the brand: pace, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: clorox, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: spice world, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: blue buffalo, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: atkins, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: dixon, the retailer is lowes home improvement, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: dixon® safety carpenter pencil, 10 count, at lowe’s®',
#  'for the brand: kingsford, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: caseys gen store, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: greenies, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: krusteaz, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: ritas, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: lysol, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: foster, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pedigree, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: jell-o, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: taco bell, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: ready pac bistro, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pam, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pepperidge farm, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pillsbury other, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: success, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: organicgirl, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: bobs red mill, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: jif, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: hunt's, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: sabra, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: cesar, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: cesar® wet dog food, spend $20',
#  'for the brand: cesar, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: cesar® wet dog food singles',
#  'for the brand: gold medal flour, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: bibigo, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: mcalisters deli, the retailer is mcalisters deli, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: sign up for mcalister's deli rewards, tap for details",
#  'for the brand: tabasco, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pillsbury, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: mission, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pasta roni, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: gain, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: taco bell, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: iams, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: duncan hines, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: kodiak cakes, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: naturesweet, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: bisquick, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: libby's, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: meijer, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: ripple, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: country crock original, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: palmolive, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: simply organic, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: simply organic seasoning mixes or spices',
#  'for the brand: betty crocker other, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: honest, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: wesson, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: wesson® oil products',
#  'for the brand: tide, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: stove top, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: truvia, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: good culture, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: king arthur, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: simple mills, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: adams, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: meow mix, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: finish, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pine-sol, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: hersheys, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: badia, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: staedtler, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: martha white, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: baker's, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: yokes fresh market, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: bic, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: subway, the retailer is subway, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $10 at subway',
#  'for the brand: subway, the retailer is subway, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $25 at subway',
#  'for the brand: subway, the retailer is subway, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $15 at subway',
#  'for the brand: subway, the retailer is subway, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $35 at subway',
#  'for the brand: sun maid, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: the nutmeg spice co, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: goodnites, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: zumba pica, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: jet-puffed, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: near east, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: sharpie, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: ortega, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: badia kingsford, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: annie's homegrown grocery, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: sheba, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: signature brands, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pride of szeged, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: red gold, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: red gold tomato ketchup',
#  'for the brand: red gold, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: red gold tomato juice',
#  'for the brand: sentry, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: heluva good!, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: scoop away, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: hungry-man, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: chosen foods, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: chosen foods® mayo, select varieties',
#  'for the brand: chosen foods, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: chosen foods® dressings',
#  "for the brand: arby's, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: tuttorosso, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: birch benders, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: zespri, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: shape, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: bolthouse farms, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: weber seasonings, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: lestoil, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: alpine touch, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: gold medal, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: wyler's, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: lawrys, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pacific foods, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: kroger, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: temptations, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: geisslers, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: burger king, the retailer is burger king, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $15 at burger king',
#  'for the brand: oscar mayer, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: nature nate's honey, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: hidden valley ranch, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: hidden valley® ranch salad dressing or secret sauce, select varieties',
#  'for the brand: hidden valley ranch, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: hidden valley® ranch seasoning mix packet, 1 count',
#  'for the brand: hidden valley ranch, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: hidden valley® ranch seasoning, select varieties',
#  'for the brand: hidden valley ranch, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: hidden valley® ranch seasoning shaker',
#  'for the brand: hidden valley ranch, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: hidden valley® ranch night seasoning mix, 1 count',
#  'for the brand: honey stinger, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: quaker, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: mr beer, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pbfit, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: resolve, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: leinenkugel's, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: oven fry, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: kodiak cups, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: local hive, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: tilex, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: annies homegrown grocery other, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: sujata, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: sure-jell, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: chef boyardee, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: woolite, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: capstar, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: pancho's, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: ajax, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: heinz, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: blue ribbon, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: s.o.s, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: annies homegrown grocery, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: any general mills™ products, buy 2\ngood rewards members only',
#  'for the brand: annies homegrown grocery, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: general mills™ products, select brands, spend $35',
#  'for the brand: annies homegrown grocery, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: general mills™ products, select brands, spend $7 at convenience stores',
#  'for the brand: annies homegrown grocery, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: general mills™ products, select varieties, spend $12',
#  "for the brand: mickey's, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: craft a brew, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: redd's wicked, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: brummel & brown, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: skinnypop, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: muir glen, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: kradle, the retailer is walmart, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: kradle, select varieties, spend $20 at walmart',
#  'for the brand: kradle, the retailer is chewy, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: kradle, select products, online at chewy.com',
#  'for the brand: kradle, the retailer is amazon, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: kradle, select varieties, online at amazon',
#  'for the brand: kradle, the retailer is pet supplies plus, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: kradle, select varieties, at pet supplies plus',
#  'for the brand: expo, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: nextstar, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: brooklyn brew shop, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: armour star, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: log cabin, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: dream whip, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: king arthur flour, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: bjs wholesale, the retailer is bjs wholesale, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: sign up for the club card or the club+ card full-priced membership* (new members only)',
#  'for the brand: reeses, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: ischolar, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: not available, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: little caesars, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: splenda stevia, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: dentastix, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: progresso, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pampers, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: good earth, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: itz spritz variety pack, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: red pack, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: fresh express, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: order from casey's app or caseys.com",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $25 at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $5 in-store at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: select beverages and prepared food items at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: visit or order online from casey's 7 times",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $5 on single-serve prepared food items at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: 12 pack or 2 liter and whole pizza pie at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: whole pizza at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: wings or cheesy breadsticks at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: whole pizza pie at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: frozen or fountain drink at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $10 in-store at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: fresh bakery item, select varieties, at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: whole pizza at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: 12 pack or 2 liter and whole pizza at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: frozen or fountain drink at casey's ",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: visit or order online from casey's 3 times",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: visit or order online from casey's 5 times",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: 12 pack or 2 liter and whole pizza at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: whole pizza at casey's ",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: fresh bakery products at casey's, select varieties",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $10 on casey's branded packaged products",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: 2 pack or 2 liter and whole pizza at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: select beverages and prepared food item at casey's",
#  "for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: fresh bakery items, select varieties, at casey's",
#  'for the brand: caseys general store, the retailer is caseys general store, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $5 on brisket mac & cheese sandwich or other single-serve prepared food item',
#  'for the brand: the good stuff, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: good natured, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: sells, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: simple truth, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pepperidge farm, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: cvs, the retailer is cvs, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $10 at cvs',
#  'for the brand: cvs, the retailer is cvs, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $30 at cvs',
#  'for the brand: fresh step, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: fresh step® outstretch® cat litter',
#  'for the brand: seventh generation, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: pilsner urquell, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: bio oil, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: bio-oil® skincare oil or gel, select varieties',
#  'for the brand: bio oil, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: bio-oil® products, select varieties',
#  "for the brand: mrs. paul's, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: halo top baking, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: jiffy, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: coombs family farms, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: kodiak on-the-go cups, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: taste republic, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: continental mills ghirardelli, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: molson canadian, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: once upon a farm, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: star market, the retailer is star market, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $90 at star market',
#  'for the brand: star market, the retailer is star market, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: shop 2 times at star market',
#  'for the brand: star market, the retailer is star market, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $120 at star market',
#  'for the brand: star market, the retailer is star market, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $220 at star market',
#  'for the brand: star market, the retailer is star market, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: any star market receipt',
#  'for the brand: private label, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: weber, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: revival, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: garden fresh gourmet, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: king arthur ap flour, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: publix, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: shaws, the retailer is shaws, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $140 at shaws',
#  'for the brand: shaws, the retailer is shaws, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $185 at shaws',
#  "for the brand: shaws, the retailer is shaws, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: shop 2 times at shaw's",
#  "for the brand: shaws, the retailer is shaws, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: any shaw's receipt",
#  'for the brand: shaws, the retailer is shaws, the product category is cooking & baking, which belongs to parent category pantry, now the offer is: spend $300 at shaws',
#  'for the brand: crisco, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: mccormick, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: marrobone, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: tajin, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: roni, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: shake n' bake, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: southern living, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: la banderita, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: vivvi & bloom, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: hungry jack, the retailer is , the product category is cooking & baking, which belongs to parent category pantry, now the offer is: ',
# ...
#  'for the brand: enfamil, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  "for the brand: earth's best, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ",
#  'for the brand: happy baby, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: pampers, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: sprout, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  "for the brand: mott's, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ",
#  'for the brand: johnsons, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: shea moisture, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: aveeno baby, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: baby dove, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: happy tot, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: plum organics, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: similac, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: the honest co., the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: nanit, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: simple truth, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: miku, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: beech nut, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: baby soft expressions, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: organics happy baby, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: a+d, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: munchkin, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: vivvi & bloom, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: enfagrow, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: horizon (whitewave foods), the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  "for the brand: dr brown's, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ",
#  'for the brand: greenwise, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: nature baby care, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: nutramigen, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: babyganics, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: hot-kid, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: cerebelly, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: baby love, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: aveeno, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: smart care, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  "for the brand: luv n' care, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ",
#  'for the brand: lansinoh, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  'for the brand: pipette, the retailer is , the product category is baby bathing, which belongs to parent category baby & toddler, now the offer is: ',
#  "for the brand: hellmann's/best foods, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: heinz, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: hellmanns best foods, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: hellmann's® or best foods® garlic aioli or spicy mayonnaise",
#  "for the brand: hellmanns best foods, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: hellmann's® or best foods® and sargento® cheese slices",
#  "for the brand: hellmanns best foods, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: hellmann's | best foods vegan dressing or spread",
#  "for the brand: hunt's, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ",
#  'for the brand: grey poupon, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: kraft, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: sir kensingtons, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: sir kensington's® condiments, buy 2",
#  "for the brand: sir kensingtons, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: sir kensington's® condiments",
#  'for the brand: ragu, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: maille, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: classico, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: prego, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: red gold, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: red gold tomato ketchup',
#  'for the brand: red gold, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: red gold tomato juice',
#  'for the brand: kroger, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: raos, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: guldens, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: sweet baby rays, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: frenchs, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: annies homegrown grocery other, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: chosen foods, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: chosen foods® mayo, select varieties',
#  'for the brand: chosen foods, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: chosen foods® dressings',
#  'for the brand: g hughes, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: rem brand, the retailer is , the product category is condiments, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: bob evans, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: betty crocker, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  "for the brand: mcalisters deli, the retailer is mcalisters deli, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: sign up for mcalister's deli rewards, tap for details",
#  'for the brand: krusteaz, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: ortega, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: old el paso, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: velveeta, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: back to the roots, the retailer is target, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots grow seed starting pots or germination trays, at walmart or target',
#  'for the brand: back to the roots, the retailer is walmart, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots soils, select varieties and sizes, at walmart',
#  'for the brand: back to the roots, the retailer is the home depot, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots dry plant food, 5 pounds, at the home depot',
#  "for the brand: back to the roots, the retailer is lowes home improvement, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots garden soil, 1 cubic foot, at lowe's home improvement",
#  'for the brand: back to the roots, the retailer is target, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots raised bed gardening kit with soil, seeds and plant food, at target',
#  'for the brand: back to the roots, the retailer is walmart, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots microgreens grow kit or seed refill at walmart',
#  'for the brand: back to the roots, the retailer is lowes home improvement, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots soils, select varieties and sizes, at lowes',
#  'for the brand: back to the roots, the retailer is lowes home improvement, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots soils, select varieties, at walmart or lowes',
#  'for the brand: back to the roots, the retailer is walmart, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots grow kits at walmart or the home depot',
#  'for the brand: back to the roots, the retailer is walmart, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots grow hydroponic grow kit or refill bundle at walmart',
#  'for the brand: back to the roots, the retailer is walmart, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots seeds, at walmart',
#  'for the brand: back to the roots, the retailer is target, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots organic kits and planters, at target',
#  "for the brand: back to the roots, the retailer is lowes home improvement, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots potting mix, 1 cubic foot, at lowe's home improvement",
#  'for the brand: back to the roots, the retailer is target, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots organic 3-in-1 seed starting mix 12 quart, at walmart or target',
#  'for the brand: back to the roots, the retailer is walmart, the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: back to the roots soils, select varieties, at walmart',
#  'for the brand: dole, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: idahoan, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: kitchen bouquet, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: ortega fiesta flats, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: mccain, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: kraft, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  'for the brand: taco bell, the retailer is , the product category is packaged meals & sides, which belongs to parent category pantry, now the offer is: ',
#  ...]

# %% [markdown]
# ### Encoding via Sentence Transformer

# %%
bi_encoder = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1')
bi_encoder.max_seq_length = 256
top_k = 32

# %%
offer_embeddings = bi_encoder.encode(offer_embedding_string, convert_to_tensor=True, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/325 [00:00<?, ?it/s]

# %%
offer_embeddings.shape
# Out:
# torch.Size([10376, 384])

# %% [markdown]
# ### Create String for Viewing

# %% [markdown]
# To enhance user readability, I designed a more straightforward, user-friendly output string

# %%
offer_user_string = []
for index, row in data.iterrows():
    sentence =  'brand: ' + row['brand'] + ' | retailer: ' + row['retailer'] + ' | category: ' + row['child_category'] + ' | parent category: ' + row['parent category'] + ' | offer: ' + row['offer']
    offer_user_string.append(sentence)

# %%
offer_user_string
# Out:
# ['brand: prego | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: ragu | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: classico | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: heb | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: barilla | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: barilla® pesto sauce',
#  'brand: barilla | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: barilla® pasta, select varieties, buy 2',
#  'brand: barilla | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: barilla® pasta, select varieties, buy 3',
#  'brand: barilla | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: barilla® pasta, select varieties, buy 4',
#  'brand: barilla | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: barilla® pasta, select varieties, buy 2',
#  'brand: the silver palate | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: publix | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  "brand: rao's | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: michael angelo's® or rao's® frozen entrees, spend $10",
#  "brand: rao's | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: rao's® frozen pizza",
#  "brand: rao's | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: rao's®, pasta or sauce, spend $10",
#  'brand: hill country fare | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: raos | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: kens | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: kroger | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: francesco rinaldi | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: simple truth | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: greenwise | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: private selection | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: bertolli | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: signature select | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: heb organics | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: weis | retailer:  | category: red pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: classico | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: prego | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: ragu | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: ',
#  "brand: rao's | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: michael angelo's® or rao's® frozen entrees, spend $10",
#  "brand: rao's | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: rao's® frozen pizza",
#  "brand: rao's | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: rao's®, pasta or sauce, spend $10",
#  'brand: kroger | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: simple truth | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: publix | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: heb | retailer:  | category: alfredo & white pasta sauce | parent category: pasta sauce | offer: ',
#  'brand: old el paso | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: kinders | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: betty crocker | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: goya | retailer:  | category: cooking & baking | parent category: pantry | offer: goya® coconut water',
#  'brand: goya | retailer:  | category: cooking & baking | parent category: pantry | offer: goya® adobo seasoning, 8 ounce+',
#  'brand: dole | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: knorr | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: dr pepper | retailer: united supermarkets | category: cooking & baking | parent category: pantry | offer: dr pepper®, regular or zero sugar strawberries and cream 12 pack, at select retailers',
#  'brand: pace | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: clorox | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: spice world | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: blue buffalo | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: atkins | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: dixon | retailer: lowes home improvement | category: cooking & baking | parent category: pantry | offer: dixon® safety carpenter pencil, 10 count, at lowe’s®',
#  'brand: kingsford | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: caseys gen store | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: greenies | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: krusteaz | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: ritas | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: lysol | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: foster | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pedigree | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: jell-o | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: taco bell | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: ready pac bistro | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pam | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pepperidge farm | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pillsbury other | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: success | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: organicgirl | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: bobs red mill | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: jif | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: hunt's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: sabra | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: cesar | retailer:  | category: cooking & baking | parent category: pantry | offer: cesar® wet dog food, spend $20',
#  'brand: cesar | retailer:  | category: cooking & baking | parent category: pantry | offer: cesar® wet dog food singles',
#  'brand: gold medal flour | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: bibigo | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: mcalisters deli | retailer: mcalisters deli | category: cooking & baking | parent category: pantry | offer: sign up for mcalister's deli rewards, tap for details",
#  'brand: tabasco | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pillsbury | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: mission | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pasta roni | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: gain | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: taco bell | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: iams | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: duncan hines | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: kodiak cakes | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: naturesweet | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: bisquick | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: libby's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: meijer | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: ripple | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: country crock original | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: palmolive | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: simply organic | retailer:  | category: cooking & baking | parent category: pantry | offer: simply organic seasoning mixes or spices',
#  'brand: betty crocker other | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: honest | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: wesson | retailer:  | category: cooking & baking | parent category: pantry | offer: wesson® oil products',
#  'brand: tide | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: stove top | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: truvia | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: good culture | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: king arthur | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: simple mills | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: adams | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: meow mix | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: finish | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pine-sol | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: hersheys | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: badia | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: staedtler | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: martha white | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: baker's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: yokes fresh market | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: bic | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: subway | retailer: subway | category: cooking & baking | parent category: pantry | offer: spend $10 at subway',
#  'brand: subway | retailer: subway | category: cooking & baking | parent category: pantry | offer: spend $25 at subway',
#  'brand: subway | retailer: subway | category: cooking & baking | parent category: pantry | offer: spend $15 at subway',
#  'brand: subway | retailer: subway | category: cooking & baking | parent category: pantry | offer: spend $35 at subway',
#  'brand: sun maid | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: the nutmeg spice co | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: goodnites | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: zumba pica | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: jet-puffed | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: near east | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: sharpie | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: ortega | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: badia kingsford | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: annie's homegrown grocery | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: sheba | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: signature brands | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pride of szeged | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: red gold | retailer:  | category: cooking & baking | parent category: pantry | offer: red gold tomato ketchup',
#  'brand: red gold | retailer:  | category: cooking & baking | parent category: pantry | offer: red gold tomato juice',
#  'brand: sentry | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: heluva good! | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: scoop away | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: hungry-man | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: chosen foods | retailer:  | category: cooking & baking | parent category: pantry | offer: chosen foods® mayo, select varieties',
#  'brand: chosen foods | retailer:  | category: cooking & baking | parent category: pantry | offer: chosen foods® dressings',
#  "brand: arby's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: tuttorosso | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: birch benders | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: zespri | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: shape | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: bolthouse farms | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: weber seasonings | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: lestoil | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: alpine touch | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: gold medal | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: wyler's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: lawrys | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pacific foods | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: kroger | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: temptations | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: geisslers | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: burger king | retailer: burger king | category: cooking & baking | parent category: pantry | offer: spend $15 at burger king',
#  'brand: oscar mayer | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: nature nate's honey | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: hidden valley ranch | retailer:  | category: cooking & baking | parent category: pantry | offer: hidden valley® ranch salad dressing or secret sauce, select varieties',
#  'brand: hidden valley ranch | retailer:  | category: cooking & baking | parent category: pantry | offer: hidden valley® ranch seasoning mix packet, 1 count',
#  'brand: hidden valley ranch | retailer:  | category: cooking & baking | parent category: pantry | offer: hidden valley® ranch seasoning, select varieties',
#  'brand: hidden valley ranch | retailer:  | category: cooking & baking | parent category: pantry | offer: hidden valley® ranch seasoning shaker',
#  'brand: hidden valley ranch | retailer:  | category: cooking & baking | parent category: pantry | offer: hidden valley® ranch night seasoning mix, 1 count',
#  'brand: honey stinger | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: quaker | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: mr beer | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pbfit | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: resolve | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: leinenkugel's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: oven fry | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: kodiak cups | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: local hive | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: tilex | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: annies homegrown grocery other | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: sujata | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: sure-jell | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: chef boyardee | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: woolite | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: capstar | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: pancho's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: ajax | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: heinz | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: blue ribbon | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: s.o.s | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: annies homegrown grocery | retailer:  | category: cooking & baking | parent category: pantry | offer: any general mills™ products, buy 2\ngood rewards members only',
#  'brand: annies homegrown grocery | retailer:  | category: cooking & baking | parent category: pantry | offer: general mills™ products, select brands, spend $35',
#  'brand: annies homegrown grocery | retailer:  | category: cooking & baking | parent category: pantry | offer: general mills™ products, select brands, spend $7 at convenience stores',
#  'brand: annies homegrown grocery | retailer:  | category: cooking & baking | parent category: pantry | offer: general mills™ products, select varieties, spend $12',
#  "brand: mickey's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: craft a brew | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: redd's wicked | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: brummel & brown | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: skinnypop | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: muir glen | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: kradle | retailer: walmart | category: cooking & baking | parent category: pantry | offer: kradle, select varieties, spend $20 at walmart',
#  'brand: kradle | retailer: chewy | category: cooking & baking | parent category: pantry | offer: kradle, select products, online at chewy.com',
#  'brand: kradle | retailer: amazon | category: cooking & baking | parent category: pantry | offer: kradle, select varieties, online at amazon',
#  'brand: kradle | retailer: pet supplies plus | category: cooking & baking | parent category: pantry | offer: kradle, select varieties, at pet supplies plus',
#  'brand: expo | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: nextstar | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: brooklyn brew shop | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: armour star | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: log cabin | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: dream whip | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: king arthur flour | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: bjs wholesale | retailer: bjs wholesale | category: cooking & baking | parent category: pantry | offer: sign up for the club card or the club+ card full-priced membership* (new members only)',
#  'brand: reeses | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: ischolar | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: not available | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: little caesars | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: splenda stevia | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: dentastix | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: progresso | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pampers | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: good earth | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: itz spritz variety pack | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: red pack | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: fresh express | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: order from casey's app or caseys.com",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: spend $25 at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: spend $5 in-store at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: select beverages and prepared food items at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: visit or order online from casey's 7 times",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: spend $5 on single-serve prepared food items at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: 12 pack or 2 liter and whole pizza pie at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: whole pizza at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: wings or cheesy breadsticks at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: whole pizza pie at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: frozen or fountain drink at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: spend $10 in-store at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: fresh bakery item, select varieties, at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: whole pizza at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: 12 pack or 2 liter and whole pizza at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: frozen or fountain drink at casey's ",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: visit or order online from casey's 3 times",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: visit or order online from casey's 5 times",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: 12 pack or 2 liter and whole pizza at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: whole pizza at casey's ",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: fresh bakery products at casey's, select varieties",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: spend $10 on casey's branded packaged products",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: 2 pack or 2 liter and whole pizza at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: select beverages and prepared food item at casey's",
#  "brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: fresh bakery items, select varieties, at casey's",
#  'brand: caseys general store | retailer: caseys general store | category: cooking & baking | parent category: pantry | offer: spend $5 on brisket mac & cheese sandwich or other single-serve prepared food item',
#  'brand: the good stuff | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: good natured | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: sells | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: simple truth | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pepperidge farm | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: cvs | retailer: cvs | category: cooking & baking | parent category: pantry | offer: spend $10 at cvs',
#  'brand: cvs | retailer: cvs | category: cooking & baking | parent category: pantry | offer: spend $30 at cvs',
#  'brand: fresh step | retailer:  | category: cooking & baking | parent category: pantry | offer: fresh step® outstretch® cat litter',
#  'brand: seventh generation | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pilsner urquell | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: bio oil | retailer:  | category: cooking & baking | parent category: pantry | offer: bio-oil® skincare oil or gel, select varieties',
#  'brand: bio oil | retailer:  | category: cooking & baking | parent category: pantry | offer: bio-oil® products, select varieties',
#  "brand: mrs. paul's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: halo top baking | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: jiffy | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: coombs family farms | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: kodiak on-the-go cups | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: taste republic | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: continental mills ghirardelli | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: molson canadian | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: once upon a farm | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: star market | retailer: star market | category: cooking & baking | parent category: pantry | offer: spend $90 at star market',
#  'brand: star market | retailer: star market | category: cooking & baking | parent category: pantry | offer: shop 2 times at star market',
#  'brand: star market | retailer: star market | category: cooking & baking | parent category: pantry | offer: spend $120 at star market',
#  'brand: star market | retailer: star market | category: cooking & baking | parent category: pantry | offer: spend $220 at star market',
#  'brand: star market | retailer: star market | category: cooking & baking | parent category: pantry | offer: any star market receipt',
#  'brand: private label | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: weber | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: revival | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: garden fresh gourmet | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: king arthur ap flour | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: publix | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: shaws | retailer: shaws | category: cooking & baking | parent category: pantry | offer: spend $140 at shaws',
#  'brand: shaws | retailer: shaws | category: cooking & baking | parent category: pantry | offer: spend $185 at shaws',
#  "brand: shaws | retailer: shaws | category: cooking & baking | parent category: pantry | offer: shop 2 times at shaw's",
#  "brand: shaws | retailer: shaws | category: cooking & baking | parent category: pantry | offer: any shaw's receipt",
#  'brand: shaws | retailer: shaws | category: cooking & baking | parent category: pantry | offer: spend $300 at shaws',
#  'brand: crisco | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: mccormick | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: marrobone | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: tajin | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: roni | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: shake n' bake | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: southern living | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: la banderita | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: vivvi & bloom | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: hungry jack | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: bertolli | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: blue apron | retailer: blue apron | category: cooking & baking | parent category: pantry | offer: blue apron meal kits',
#  'brand: grolsch lager | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: smoothie king | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: instyle | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: spring tree | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: sugar in the raw | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: viva spritz | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: pavilions | retailer: pavilions | category: cooking & baking | parent category: pantry | offer: spend $155 at pavilions',
#  'brand: pavilions | retailer: pavilions | category: cooking & baking | parent category: pantry | offer: shop 2 times at pavilions',
#  'brand: pavilions | retailer: pavilions | category: cooking & baking | parent category: pantry | offer: spend $100 at pavilions',
#  'brand: pavilions | retailer: pavilions | category: cooking & baking | parent category: pantry | offer: any pavilions receipt',
#  'brand: pavilions | retailer: pavilions | category: cooking & baking | parent category: pantry | offer: spend $270 at pavilions',
#  'brand: kernel seasons | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: on the border | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: jet puffed | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: wolfgang puck | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: ecce panis | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: jet-puffed | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: zulka | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: playtex | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: stevia in the raw | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: morton | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: epic | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  "brand: pf chang's | retailer:  | category: cooking & baking | parent category: pantry | offer: ",
#  'brand: 7now | retailer:  | category: cooking & baking | parent category: pantry | offer: ',
#  'brand: temptations | retailer:  | category: packaged seafood | parent category: pantry | offer: ',
#  'brand: meow mix | retailer:  | category: packaged seafood | parent category: pantry | offer: ',
#  'brand: good seasons | retailer:  | category: packaged seafood | parent category: pantry | offer: ',
#  'brand: sheba | retailer:  | category: packaged seafood | parent category: pantry | offer: ',
#  'brand: rachael ray nutrish | retailer:  | category: packaged seafood | parent category: pantry | offer: ',
#  'brand: reveal natural cat food | retailer:  | category: packaged seafood | parent category: pantry | offer: ',
#  'brand: applaws | retailer:  | category: packaged seafood | parent category: pantry | offer: ',
#  'brand: blue buffalo | retailer:  | category: packaged seafood | parent category: pantry | offer: ',
#  'brand: goya | retailer:  | category: packaged seafood | parent category: pantry | offer: goya® coconut water',
#  'brand: goya | retailer:  | category: packaged seafood | parent category: pantry | offer: goya® adobo seasoning, 8 ounce+',
#  'brand: u by kotex | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: always | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: tampax | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: carefree | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: safe & soft | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: hanes | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: biolyte | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: intimina | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: tampax pocket radiant | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: seventh generation | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: incognito | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: cora | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: rael | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: nature made | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  'brand: tampax pearl | retailer:  | category: feminine hygeine | parent category: health & wellness | offer: ',
#  "brand: mcalisters deli | retailer: mcalisters deli | category: leafy salads | parent category: deli & bakery | offer: sign up for mcalister's deli rewards, tap for details",
#  'brand: dole | retailer:  | category: leafy salads | parent category: deli & bakery | offer: ',
#  'brand: white wave land o lakes | retailer:  | category: cream | parent category: dairy | offer: ',
#  'brand: garelick farms | retailer:  | category: cream | parent category: dairy | offer: ',
#  'brand: daisy | retailer:  | category: cream | parent category: dairy | offer: ',
#  'brand: starbucks | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: folgers | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: dunkin | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: cafe bustelo | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: international delight | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: califia farms | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: nescafe | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: starbucks coffee | retailer:  | category: coffee | parent category: beverages | offer: ',
#  "brand: dunkin' donuts | retailer:  | category: coffee | parent category: beverages | offer: ",
#  'brand: chobani | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: gevalia | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: counter culture coffee | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: super coffee | retailer:  | category: coffee | parent category: beverages | offer: super coffee, 12 ounce single serve, buy 3',
#  'brand: super coffee | retailer:  | category: coffee | parent category: beverages | offer: super coffee, 12 ounce single serve',
#  'brand: maxwell house | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: green mountain coffee | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: eight oclock | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: kroger | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: la colombe | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: private selection | retailer:  | category: coffee | parent category: beverages | offer: ',
#  "brand: mcalisters deli | retailer: mcalisters deli | category: coffee | parent category: beverages | offer: sign up for mcalister's deli rewards, tap for details",
#  'brand: cafe la llave | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: mccafe | retailer:  | category: coffee | parent category: beverages | offer: ',
#  "brand: dunkin' | retailer:  | category: coffee | parent category: beverages | offer: ",
#  'brand: java monster | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: bolthouse farms | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: maxwell house | retailer:  | category: coffee | parent category: beverages | offer: ',
#  "brand: cameron's coffee | retailer:  | category: coffee | parent category: beverages | offer: cameron’s coffee ecopods",
#  'brand: chock full o nuts | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: simple truth | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: stok | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: nestle | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: chameleon coffee | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: cinnabon | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: krispy kreme | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: lavazza | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: yuban coffee | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: pillsbury | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: dunkin donuts | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: tim hortons coffee | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: death wish coffee co | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: mad bean vanilla iced coffee | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: gevalia coffee | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: 81bay coffee porter | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: mad bean mocha iced coffee | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: chameleon cold brew | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: intl delight | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: medaglia doro | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: coca cola | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: reddi wip | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: silk | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: kitu | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: torani | retailer:  | category: coffee | parent category: beverages | offer: ',
#  'brand: outshine | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: 7 eleven | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: minute maid | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: goya | retailer:  | category: frozen fruits | parent category: frozen | offer: goya® coconut water',
#  'brand: goya | retailer:  | category: frozen fruits | parent category: frozen | offer: goya® adobo seasoning, 8 ounce+',
#  'brand: ush blueberries | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: dole foods | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: jel sert | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: popsicle | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: cascadian farm frozen | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: dole | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: fun treats | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: frutero | retailer:  | category: frozen fruits | parent category: frozen | offer: frutero ice cream, 1 pint',
#  'brand: cascadian farm | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: halo top | retailer:  | category: frozen fruits | parent category: frozen | offer: ',
#  'brand: jif | retailer:  | category: nut butters & jam | parent category: pantry | offer: ',
#  'brand: smuckers uncrustables | retailer:  | category: nut butters & jam | parent category: pantry | offer: ',
#  'brand: smuckers | retailer:  | category: nut butters & jam | parent category: pantry | offer: ',
#  'brand: ready pac bistro | retailer:  | category: nut butters & jam | parent category: pantry | offer: ',
#  'brand: nature valley | retailer:  | category: nut butters & jam | parent category: pantry | offer: nature valley™ protein granola',
#  "brand: land o' lakes | retailer:  | category: nut butters & jam | parent category: pantry | offer: ",
#  'brand: country crock plant butter | retailer: walmart | category: nut butters & jam | parent category: pantry | offer: country crock® plant based butter at walmart',
#  'brand: country crock plant butter | retailer: walmart | category: nut butters & jam | parent category: pantry | offer: country crock® plant based cream at walmart',
#  'brand: butterball | retailer: dillons food store | category: nut butters & jam | parent category: pantry | offer: butterball, select varieties, spend $10 at dillons food store',
#  'brand: butterball | retailer: ralphs | category: nut butters & jam | parent category: pantry | offer: butterball, select varieties, spend $10 at ralphs',
#  'brand: butterball | retailer: ruler foods | category: nut butters & jam | parent category: pantry | offer: butterball, select varieties, spend $10 at ruler foods',
#  'brand: butterball | retailer: king soopers | category: nut butters & jam | parent category: pantry | offer: butterball, select varieties, spend $10 at king soopers',
#  'brand: butterball | retailer: fred meyer | category: nut butters & jam | parent category: pantry | offer: butterball, select varieties, spend $10 at fred meyer',
# ...
#  "brand: odom's tennessee pride | retailer:  | category: frozen meals | parent category: frozen | offer: ",
#  'brand: tyson | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  "brand: p.f. chang's home menu | retailer:  | category: frozen meals | parent category: frozen | offer: ",
#  'brand: rao’s | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: sea cuisine | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: goya | retailer:  | category: frozen meals | parent category: frozen | offer: goya® coconut water',
#  'brand: goya | retailer:  | category: frozen meals | parent category: frozen | offer: goya® adobo seasoning, 8 ounce+',
#  'brand: fisher boy | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  "brand: udi's gluten free | retailer:  | category: frozen meals | parent category: frozen | offer: ",
#  "brand: nancy's | retailer:  | category: frozen meals | parent category: frozen | offer: ",
#  'brand: michael angelo’s | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: sister schubert’s | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: jimmy dean | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: sheba | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: tinas | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: lean cuisine | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: oreo | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: hot pockets | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: annies homegrown grocery | retailer:  | category: frozen meals | parent category: frozen | offer: any general mills™ products, buy 2\ngood rewards members only',
#  'brand: annies homegrown grocery | retailer:  | category: frozen meals | parent category: frozen | offer: general mills™ products, select brands, spend $35',
#  'brand: annies homegrown grocery | retailer:  | category: frozen meals | parent category: frozen | offer: general mills™ products, select brands, spend $7 at convenience stores',
#  'brand: annies homegrown grocery | retailer:  | category: frozen meals | parent category: frozen | offer: general mills™ products, select varieties, spend $12',
#  'brand: mccain | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: clio bar | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: green giant | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: michelinas | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: birds eye | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: bellisio foods | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  'brand: stouffers | retailer:  | category: frozen meals | parent category: frozen | offer: ',
#  "brand: sister schubert's | retailer:  | category: frozen meals | parent category: frozen | offer: ",
#  "brand: gortons | retailer: shop rite | category: frozen meals | parent category: frozen | offer: gorton's, at select retailers",
#  "brand: gortons | retailer: walmart | category: frozen meals | parent category: frozen | offer: gorton's air fried butterfly shrimp, at walmart",
#  "brand: gortons | retailer: stop & shop | category: frozen meals | parent category: frozen | offer: gorton's, at select retailers",
#  "brand: gortons | retailer: stop & shop | category: frozen meals | parent category: frozen | offer: gorton's at select retailers",
#  "brand: gortons | retailer: walmart | category: frozen meals | parent category: frozen | offer: gorton's at select retailers",
#  'brand: screamin sicilian | retailer:  | category: frozen | parent category: frozen | offer: ',
#  'brand: jimmy dean | retailer:  | category: frozen | parent category: frozen | offer: ',
#  'brand: bob evans | retailer:  | category: frozen | parent category: frozen | offer: ',
#  'brand: johnsonville | retailer:  | category: frozen | parent category: frozen | offer: ',
#  'brand: bob evans® dinner sides | retailer:  | category: dairy | parent category: dairy | offer: ',
#  'brand: hodo | retailer:  | category: dairy | parent category: dairy | offer: ',
#  'brand: baby soft | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: predo | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: gerber | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: enfamil | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  "brand: earth's best | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ",
#  'brand: happy baby | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: pampers | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: sprout | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  "brand: mott's | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ",
#  'brand: johnsons | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: shea moisture | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: aveeno baby | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: baby dove | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: happy tot | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: plum organics | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: similac | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: the honest co. | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: nanit | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: simple truth | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: miku | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: beech nut | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: baby soft expressions | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: organics happy baby | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: a+d | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: munchkin | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: vivvi & bloom | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: enfagrow | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: horizon (whitewave foods) | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  "brand: dr brown's | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ",
#  'brand: greenwise | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: nature baby care | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: nutramigen | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: babyganics | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: hot-kid | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: cerebelly | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: baby love | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: aveeno | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: smart care | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  "brand: luv n' care | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ",
#  'brand: lansinoh | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  'brand: pipette | retailer:  | category: baby bathing | parent category: baby & toddler | offer: ',
#  "brand: hellmann's/best foods | retailer:  | category: condiments | parent category: pantry | offer: ",
#  'brand: heinz | retailer:  | category: condiments | parent category: pantry | offer: ',
#  "brand: hellmanns best foods | retailer:  | category: condiments | parent category: pantry | offer: hellmann's® or best foods® garlic aioli or spicy mayonnaise",
#  "brand: hellmanns best foods | retailer:  | category: condiments | parent category: pantry | offer: hellmann's® or best foods® and sargento® cheese slices",
#  "brand: hellmanns best foods | retailer:  | category: condiments | parent category: pantry | offer: hellmann's | best foods vegan dressing or spread",
#  "brand: hunt's | retailer:  | category: condiments | parent category: pantry | offer: ",
#  'brand: grey poupon | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: kraft | retailer:  | category: condiments | parent category: pantry | offer: ',
#  "brand: sir kensingtons | retailer:  | category: condiments | parent category: pantry | offer: sir kensington's® condiments, buy 2",
#  "brand: sir kensingtons | retailer:  | category: condiments | parent category: pantry | offer: sir kensington's® condiments",
#  'brand: ragu | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: maille | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: classico | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: prego | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: red gold | retailer:  | category: condiments | parent category: pantry | offer: red gold tomato ketchup',
#  'brand: red gold | retailer:  | category: condiments | parent category: pantry | offer: red gold tomato juice',
#  'brand: kroger | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: raos | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: guldens | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: sweet baby rays | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: frenchs | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: annies homegrown grocery other | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: chosen foods | retailer:  | category: condiments | parent category: pantry | offer: chosen foods® mayo, select varieties',
#  'brand: chosen foods | retailer:  | category: condiments | parent category: pantry | offer: chosen foods® dressings',
#  'brand: g hughes | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: rem brand | retailer:  | category: condiments | parent category: pantry | offer: ',
#  'brand: bob evans | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: betty crocker | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  "brand: mcalisters deli | retailer: mcalisters deli | category: packaged meals & sides | parent category: pantry | offer: sign up for mcalister's deli rewards, tap for details",
#  'brand: krusteaz | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: ortega | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: old el paso | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: velveeta | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: back to the roots | retailer: target | category: packaged meals & sides | parent category: pantry | offer: back to the roots grow seed starting pots or germination trays, at walmart or target',
#  'brand: back to the roots | retailer: walmart | category: packaged meals & sides | parent category: pantry | offer: back to the roots soils, select varieties and sizes, at walmart',
#  'brand: back to the roots | retailer: the home depot | category: packaged meals & sides | parent category: pantry | offer: back to the roots dry plant food, 5 pounds, at the home depot',
#  "brand: back to the roots | retailer: lowes home improvement | category: packaged meals & sides | parent category: pantry | offer: back to the roots garden soil, 1 cubic foot, at lowe's home improvement",
#  'brand: back to the roots | retailer: target | category: packaged meals & sides | parent category: pantry | offer: back to the roots raised bed gardening kit with soil, seeds and plant food, at target',
#  'brand: back to the roots | retailer: walmart | category: packaged meals & sides | parent category: pantry | offer: back to the roots microgreens grow kit or seed refill at walmart',
#  'brand: back to the roots | retailer: lowes home improvement | category: packaged meals & sides | parent category: pantry | offer: back to the roots soils, select varieties and sizes, at lowes',
#  'brand: back to the roots | retailer: lowes home improvement | category: packaged meals & sides | parent category: pantry | offer: back to the roots soils, select varieties, at walmart or lowes',
#  'brand: back to the roots | retailer: walmart | category: packaged meals & sides | parent category: pantry | offer: back to the roots grow kits at walmart or the home depot',
#  'brand: back to the roots | retailer: walmart | category: packaged meals & sides | parent category: pantry | offer: back to the roots grow hydroponic grow kit or refill bundle at walmart',
#  'brand: back to the roots | retailer: walmart | category: packaged meals & sides | parent category: pantry | offer: back to the roots seeds, at walmart',
#  'brand: back to the roots | retailer: target | category: packaged meals & sides | parent category: pantry | offer: back to the roots organic kits and planters, at target',
#  "brand: back to the roots | retailer: lowes home improvement | category: packaged meals & sides | parent category: pantry | offer: back to the roots potting mix, 1 cubic foot, at lowe's home improvement",
#  'brand: back to the roots | retailer: target | category: packaged meals & sides | parent category: pantry | offer: back to the roots organic 3-in-1 seed starting mix 12 quart, at walmart or target',
#  'brand: back to the roots | retailer: walmart | category: packaged meals & sides | parent category: pantry | offer: back to the roots soils, select varieties, at walmart',
#  'brand: dole | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: idahoan | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: kitchen bouquet | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: ortega fiesta flats | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: mccain | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: kraft | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  'brand: taco bell | retailer:  | category: packaged meals & sides | parent category: pantry | offer: ',
#  ...]

# %% [markdown]
# Mapped `offer_embedding_string` to `offer_user_string`, so that the algorithm could convert embedding strings into user-friendly output

# %%
mapping = {}
for i in range(len(offer_embedding_string)):
    key = offer_embedding_string[i]
    value = offer_user_string[i]
    mapping[key] = value

# %% [markdown]
# ### Baseline Algorithm: Cross Encoder Scoring Mechanism

# %% [markdown]
# 1. Function refer to sentence transformer repo:
# https://github.com/UKPLab/sentence-transformers/blob/master/examples/applications/retrieve_rerank/retrieve_rerank_simple_wikipedia.ipynb
#
# 2. The main idea is to use bi-encoder to encode data, and use cross-encoder to get score and rank the results

# %%
cross_encoder = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2')

# %%
def baseline_search(query):

    question_embedding = bi_encoder.encode(query, convert_to_tensor=True)
    hits = util.semantic_search(question_embedding, offer_embeddings, top_k=top_k)
    hits = hits[0]  # Get the hits for the first query
    cross_inp = [[query, offer_embedding_string[hit['corpus_id']]] for hit in hits]
    cross_scores = cross_encoder.predict(cross_inp)

    # Sort results by the cross-encoder scores
    for idx in range(len(cross_scores)):
        hits[idx]['cross-score'] = cross_scores[idx]

    hits = sorted(hits, key=lambda x: x['cross-score'], reverse=True)

    res = []
    for hit in hits[0:3]:
        embed_str = offer_embedding_string[hit["corpus_id"]]
        user_str = mapping[embed_str]
        res.append((hit['cross-score'], user_str))


    return res

# %% [markdown]
# #### chanllenges

# %% [markdown]
# The current scoring mechanism presents two major challenges:
#
# 1. **"No-offer Problem"**: Results without offers are prioritized in the top rank, while results with offers may not appear prominently. This can lead to users missing important offer information.
#
# 2. **"Typo Problem"**: The algorithm lacks flexibility in handling typos. For example, if a user types "Targt," the algorithm cannot correctly identify the retailer "target" and provide relevant results.

# %% [markdown]
# #### examples

# %% [markdown]
# Example illustrating "No-offer Problem":
# Both the first and second results do not contain any offers

# %%
baseline_search('Target')
# Out:
# [(4.451646,
#   'brand: target | retailer:  | category: deodorant & antiperspirant | parent category: health & wellness | offer: '),
#  (4.116417,
#   'brand: target | retailer:  | category: wine | parent category: alcohol | offer: '),
#  (3.2561677,
#   'brand: back to the roots | retailer: target | category: packaged meals & sides | parent category: pantry | offer: back to the roots raised bed gardening kit with soil, seeds and plant food, at target')]

# %% [markdown]
# Example illustrating "Typo Problem": Suppose the user intends to search for 'target' offers but types 'targt,' the results fails to display the 'target' offers

# %%
baseline_search('Targt')
# Out:
# [(-5.43099,
#   'brand: tarot | retailer:  | category: wine | parent category: alcohol | offer: '),
#  (-5.8334913,
#   'brand: tarima | retailer:  | category: wine | parent category: alcohol | offer: '),
#  (-6.839417,
#   'brand: earth rider blackbecrush tart wheat ale | retailer:  | category: beer | parent category: alcohol | offer: ')]

# %% [markdown]
# ### Improved Algorithm: Ngram Fuzzy Search + Cross Encoder + Rerank Scoring Mechanism

# %% [markdown]
# To address the two issues mentioned earlier, I have made improvements as follows:
#
# 1. **"Typo Problem"**: Introduced Ngram fuzzy search to improve typo identification, ensuring better accuracy in recognizing user queries with typo errors
#
#
# 2. **"No-offer Problem"**: Add a rank function and designed specific reranking strategy:
#     - Select the top 5 search results based on relevance
#     - Filter all results to identify the top 5 results that include offers
#     - Combine the top 5 search results and top 5 filtered results,  rerank them based on their scores to generate the final output

# %%
def deduplicate(input_list):
    return sorted(set(input_list))

# %%
def get_obj_string_list(name):
    obj_string = []
    for index, row in data.iterrows():
        sentence =  row[name] 
        if not pd.isna(sentence) and sentence != "":
            obj_string.append(sentence.lower())
    return deduplicate(obj_string)

# %%
def get_ngrams(name, n):
    characters = [c for c in name.lower()]
    return list(ngrams(characters, n))

# %%
def ngram_fuzzy_search(search_text):
    retail_string = get_obj_string_list("retailer")
    brand_string = get_obj_string_list("brand")
    cat_string = deduplicate(get_obj_string_list("child_category") + get_obj_string_list("parent category"))
    entry_string = deduplicate(cat_string + brand_string + retail_string)
    
    input_text = search_text
    n = 2
    input_ngrams = get_ngrams(input_text, n)
    similarities = []
    
    for entry in entry_string:
        entry_ngrams = get_ngrams(entry, n)
        similarity = 1 - jaccard_distance(set(input_ngrams), set(entry_ngrams))
        similarities.append((similarity, entry))
        
    threshold = 0.3
    k = 3
    filtered_similarities = [(similarity, entry) for similarity, entry in similarities if similarity >= threshold]
    sorted_similarities = sorted(filtered_similarities, key=lambda x: x[0], reverse=True)
    queries = sorted_similarities[:k]
#     input_text = "targt"
    return queries

# %%
def cross_encode(encode_name):
    queries = ngram_fuzzy_search(encode_name)
    res = []

    for query_sim, query in queries:
        question_embedding = bi_encoder.encode(query, convert_to_tensor=True)
        hits = util.semantic_search(question_embedding, offer_embeddings, top_k=top_k)
        hits = hits[0]  # Get the hits for the first query
        cross_inp = [[query, offer_embedding_string[hit['corpus_id']]] for hit in hits]
        cross_scores = cross_encoder.predict(cross_inp)

        # Sort results by the cross-encoder scores
        for idx in range(len(cross_scores)):
            hits[idx]['cross-score'] = cross_scores[idx]
        
        for hit in hits:
            embed_str = offer_embedding_string[hit["corpus_id"]]
            user_str = mapping[embed_str]
            have_offer =  not user_str.strip().endswith("offer:")
            res.append((hit['cross-score'], user_str, have_offer, query_sim, query))
            
    res = sorted(res, key=lambda x:x[0], reverse=True)
    return res

# %%
def my_search(search_name):
    DEBUG=False
    offer_list = cross_encode(search_name)
    res = []
    updated_offer_list = []
    for offer in offer_list:
        cross_score, user_str, have_offer, query_score, query = offer
        combined_score = cross_score + 10*query_score
        updated_offer_list.append((combined_score, have_offer, user_str, query))        
    
    updated_offer_list = sorted(updated_offer_list, key=lambda x: x[0], reverse=True)
    if DEBUG:
        print("===============VIS================")
        for offer in updated_offer_list[:20]:
            print("score:", offer[0], "have_offer:", offer[1], "user_str:", offer[2])
            print("=====")
    
    with_offer = [offer for offer in updated_offer_list if offer[1]]
    with_offer_sorted = sorted(with_offer,key=lambda x: x[0], reverse=True)
    for offer in with_offer_sorted[0:5]:
        res.append((offer[0],offer[2]))
    
    for offer in updated_offer_list[0:5]:
        if (offer[0],offer[2]) in res:
            continue
        res.append((offer[0], offer[2]))
                
    return list(res)

# %% [markdown]
# #### examples

# %% [markdown]
# Example addressing "No-offer Problem": records with offers now appear prominently at the top of the search results

# %%
my_search('target')
# Out:
# [(13.256167650222778,
#   'brand: back to the roots | retailer: target | category: packaged meals & sides | parent category: pantry | offer: back to the roots raised bed gardening kit with soil, seeds and plant food, at target'),
#  (12.702252864837646,
#   'brand: back to the roots | retailer: target | category: packaged meals & sides | parent category: pantry | offer: back to the roots organic kits and planters, at target'),
#  (12.657567977905273,
#   "brand: loreal paris cosmetics | retailer: target | category: makeup | parent category: beauty | offer: l'oreal paris true match foundation at target"),
#  (12.657567977905273,
#   "brand: loreal paris cosmetics | retailer: target | category: makeup | parent category: beauty | offer: l'oréal paris true match foundation at target"),
#  (12.459017992019653,
#   'brand: dove | retailer: target | category: hair care | parent category: health & wellness | offer: dove hand wash, select varieties at target'),
#  (14.451645851135254,
#   'brand: target | retailer:  | category: deodorant & antiperspirant | parent category: health & wellness | offer: '),
#  (14.116416931152344,
#   'brand: target | retailer:  | category: wine | parent category: alcohol | offer: ')]

# %% [markdown]
# Example addressing "Typo Problem": the algorithm can now identify typographical errors made by users and return the relevant results

# %%
my_search('targt')
# Out:
# [(8.256167650222778,
#   'brand: back to the roots | retailer: target | category: packaged meals & sides | parent category: pantry | offer: back to the roots raised bed gardening kit with soil, seeds and plant food, at target'),
#  (7.7022528648376465,
#   'brand: back to the roots | retailer: target | category: packaged meals & sides | parent category: pantry | offer: back to the roots organic kits and planters, at target'),
#  (7.657567977905273,
#   "brand: loreal paris cosmetics | retailer: target | category: makeup | parent category: beauty | offer: l'oreal paris true match foundation at target"),
#  (7.657567977905273,
#   "brand: loreal paris cosmetics | retailer: target | category: makeup | parent category: beauty | offer: l'oréal paris true match foundation at target"),
#  (7.459017992019653,
#   'brand: dove | retailer: target | category: hair care | parent category: health & wellness | offer: dove hand wash, select varieties at target'),
#  (9.451645851135254,
#   'brand: target | retailer:  | category: deodorant & antiperspirant | parent category: health & wellness | offer: '),
#  (9.116416931152344,
#   'brand: target | retailer:  | category: wine | parent category: alcohol | offer: '),
#  (8.314271767934164,
#   'brand: tarot | retailer:  | category: wine | parent category: alcohol | offer: ')]

# %% [markdown]
# Example for typing category

# %%
my_search('pantry')
# Out:
# [(10.72649073600769,
#   'brand: annies homegrown grocery | retailer:  | category: soup & broth | parent category: pantry | offer: any general mills™ products, buy 2\ngood rewards members only'),
#  (10.667452931404114,
#   'brand: annies homegrown grocery | retailer:  | category: soup & broth | parent category: pantry | offer: general mills™ products, select brands, spend $7 at convenience stores'),
#  (10.345320641994476,
#   'brand: annies homegrown grocery | retailer:  | category: soup & broth | parent category: pantry | offer: general mills™ products, select varieties, spend $12'),
#  (10.079375550150871,
#   'brand: annies homegrown grocery | retailer:  | category: cooking & baking | parent category: pantry | offer: general mills™ products, select varieties, spend $12'),
#  (-7.405521392822266,
#   'brand: gatorade | retailer: dillons grocery | category: sports drinks | parent category: sports drinks & enhanced waters | offer: gatorade® fast twitch®, 12-ounce single serve, at kroger'),
#  (11.197189927101135,
#   'brand: annies homegrown grocery other | retailer:  | category: condiments | parent category: pantry | offer: '),
#  (11.121859073638916,
#   'brand: kraft | retailer:  | category: condiments | parent category: pantry | offer: '),
#  (11.010684370994568,
#   'brand: kroger | retailer:  | category: condiments | parent category: pantry | offer: '),
#  (10.689132690429688,
#   'brand: the good stuff | retailer:  | category: cooking & baking | parent category: pantry | offer: ')]

# %% [markdown]
# Example for typing brand

# %%
my_search('subway')
# Out:
# [(15.790562629699707,
#   'brand: subway | retailer: subway | category: cooking & baking | parent category: pantry | offer: spend $25 at subway'),
#  (15.787304878234863,
#   'brand: subway | retailer: subway | category: cooking & baking | parent category: pantry | offer: spend $35 at subway'),
#  (15.780460357666016,
#   'brand: subway | retailer: subway | category: cooking & baking | parent category: pantry | offer: spend $15 at subway'),
#  (15.772863388061523,
#   'brand: subway | retailer: subway | category: cooking & baking | parent category: pantry | offer: spend $10 at subway'),
#  (-0.8557090759277344,
#   'brand: caseys general store | retailer: caseys general store | category: frozen pizza & pizza snacks | parent category: frozen | offer: spend $5 on brisket mac & cheese sandwich or other single-serve prepared food item'),
#  (-0.28975772857666016,
#   'brand: 7th avenue pizza | retailer:  | category: frozen pizza & pizza snacks | parent category: frozen | offer: ')]
